# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train),(X_test,y_test) = keras.datasets.mnist.load_data()

# %%
X_train=X_train/255
X_test = X_test/255

# %%
X_train_flattened = X_train.reshape(len(X_train),28*28)
X_test_flattened = X_test.reshape(len(X_test),28*28)
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,),activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train_flattened,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 2ms/step - loss: 9.5628 - accuracy: 0.8422
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 6.0208 - accuracy: 0.8773
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.6821 - accuracy: 0.8839
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.4029 - accuracy: 0.8862
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.3170 - accuracy: 0.8871

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation='selu'),
    keras.layers.Dense(100,activation='swish'),
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train,y_train,epochs=5)

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3017 - accuracy: 0.0984
# [2.3016698360443115, 0.09839999675750732]

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0883 - accuracy: 0.9736
# [0.08825874328613281, 0.9735999703407288]

# %%
y_predict = model.predict(X_test)
y_predict_labels = [np.argmax(i) for i in y_predict]
cm=tf.math.confusion_matrix(labels=y_test,predictions=y_predict_labels)
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Text(95.72222222222221, 0.5, 'Truth')
